# %% [markdown]
# <a href="https://colab.research.google.com/github/rezamohammadloo/hello_world/blob/main/line_fitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# hello world of deep learning

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# fiiting a line between to data with the equation of :
# y=2x-1

# %%
x = np.array([-1, 0, 1, 2, 3, 4], dtype= float)
y = np.array([-3, -1, 1, 3, 5, 7], dtype=float)

# %% [markdown]
# creating our model

# %%
model=keras.Sequential([
keras.layers.Dense(1, input_shape=[1])
])

# %% [markdown]
# compiling the model

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# fitting the data

# %%
model.fit(x, y, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 600ms/step - loss: 16.0321
# Epoch 2/500
# 1/1 [==============================] - 0s 15ms/step - loss: 12.8591
# Epoch 3/500
# 1/1 [==============================] - 0s 10ms/step - loss: 10.3577
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 8.3847
# Epoch 5/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8277
# Epoch 6/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.5979
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 4.6257
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.8563
# Epoch 9/500
# 1/1 [==============================] - 0s 12ms/step - loss: 3.2465
# Epoch 10/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.7624
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3773
# Epoch 12/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0701
# ...

# %% [markdown]
# making a prediction

# %%
print(model.predict([10]))
# Out:
# 1/1 [==============================] - 0s 34ms/step
# [[18.981424]]
